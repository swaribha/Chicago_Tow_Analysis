# %%
#Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
import csv
import gmaps
import seaborn as sns

# %%
file ="Data/vehicles.csv"
vehicles_df = pd.read_csv(file)
vehicles_df.head()
# Out:
#      Tow Date  Make Style Color    Plate State     Towed to Address  \
# 0  2019-03-21  ACUR    4T   BLK  AZ38933    IL    701 N. Sacramento
# 1  2019-03-21  ACUR    LL   SIL  E695295    IL  400 E. Lower Wacker
# 2  2019-03-21  AUDI    LL   BLK  AW30759    IL    701 N. Sacramento
# 3  2019-03-21  AUDI    SW   DBL  TAIRRE1    IL    701 N. Sacramento
# 4  2019-03-21   BMW    LL   BLK  AT56204    IL    701 N. Sacramento
#
#   Tow Facility Phone  Inventory Number day_of_week
# 0     (773) 265-7605           6954475    Thursday
# 1     (312) 744-7550           6954505    Thursday
# 2     (773) 265-7605           6954521    Thursday
# 3     (773) 265-7605           6954552    Thursday
# 4     (773) 265-7605           6954562    Thursday

# %%
# #Question 5: To which facility is a car most likely towed?
# # Dependencies
# import requests
# import json

# # Google developer API key
# from config import gkey

# # Target city
# target_address = "10255 W. Zemke Blvd, Chicago, Illinois"

# # Build the endpoint URL
# target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
#     'address={0}&key={1}').format(target_address, gkey)

# %%
import csv

with open('address.csv', 'w') as csvfile:
    fieldnames = ['address', 'Lat', 'Lng', "Count"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'address': '701 N. Sacramento', 'Lat': '41.893522', 'Lng': '-87.7011050', 'Count':'2203'})
    writer.writerow({'address': '400 E. Lower Wacker', 'Lat': '41.8875727', 'Lng': '-87.615866', 'Count':'87'})
    writer.writerow({'address': '10300 S. Doty','Lat': '41.7044335', 'Lng': '-87.58761469999999', 'Count': '2315'})
    writer.writerow({'address': "Chicago O'hare International Airport remote lot E.",'Lat': '41.9926381', 'Lng': '-87.8811369', 'Count': '5'})

# %%
# import csv
file = "Data/address.csv"
address_df=pd.read_csv(file)
address_df.head()
# Out:
#                                              address        Lat        Lng  \
# 0                                  701 N. Sacramento  41.893522 -87.701105
# 1                                400 E. Lower Wacker  41.887573 -87.615866
# 2                                      10300 S. Doty  41.704434 -87.587615
# 3  Chicago O'hare International Airport remote lo...  41.992638 -87.881137
#
#    Count
# 0   2203
# 1     87
# 2   2315
# 3      5

# %%
# vehicles_df=pd.DataFrame(vehicles_df)
# address_df=pd.DataFrame(address_df)

# #Visualize
# print(len(address_df))                         
# address_df.head()

# print(len(vehicles_df))
# vehicles_df.head()

# %%
address_df_complete = pd.merge(vehicles_df, address_df, left_on='Towed to Address',
                               right_on='address',
                              how = 'inner')

address_df_complete.to_csv(
"../Project_1/address_df_complete.csv", encoding="utf-8", index=False)

#Visualize
address_df_complete
# Out:
#         Tow Date  Make Style Color     Plate State  \
# 0     2019-03-21  ACUR    4T   BLK   AZ38933    IL
# 1     2019-03-21  AUDI    LL   BLK   AW30759    IL
# 2     2019-03-21  AUDI    SW   DBL   TAIRRE1    IL
# 3     2019-03-21   BMW    LL   BLK   AT56204    IL
# 4     2019-03-21  BUIC    4D   GRN   BD73021    IL
# 5     2019-03-21  BUIC    4D   SIL   AQ71209    IL
# 6     2019-03-21  CHEV    4D   BLU   AK55467    IL
# 7     2019-03-21  CHEV    LL   DBL   ZU11859    IL
# 8     2019-03-21  CHEV    VN   GLD   AW27879    IL
# 9     2019-03-21  CHRY    4D   GRY   AJ52258    IL
# 10    2019-03-21  DODG    4D   GRY   AQ71724    IL
# 11    2019-03-21  DODG    4T   WHI   BA54384    IL
# 12    2019-03-21  DODG    LL   GRY   ZZ30931    IL
# 13    2019-03-21  DODG    VN   MAR    PVR136    IL
# 14    2019-03-21  DODG    VN   SIL    637540    IL
# 15    2019-03-21  FORD    2T   BLK   BA59118    IL
# 16    2019-03-21  FORD    4D   BLK    6741WS    IL
# ...

# %%
# address_df_complete['State'].value_counts().reindex(address_df_complete['State'].unique()).tolist()

# address_df_complete.groupby('State')['address'].size()

#pd.crosstab(address_df_complete.make, address_df_complete.body_style)
# (a,[b], rownames =['State'], colnames= ['address'])

#address_df_complete.pivot_table(index='address', columns='State', aggfunc={'State':len}, fill_value=0)

#sns.heatmap(pd.crosstab([df.make, df.num_doors], [df.body_style, df.drive_wheels]),
#            cmap="YlGnBu", annot=True, cbar=False)

# new_df = pd.crosstab(address_df_complete.State, address_df_complete.address, normalize=True)
# new_df = new_df.rename(columns={"Chicago O'hare International Airport remote lot E.": "ORD"})

# # sns.heatmap(pd.crosstab([address_df_complete.State], [address_df_complete.address]),
# #             cmap=YlGnBu", vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# # address_df_complete
# new_df.head()

# %%
address_df_complete["address"] = address_df_complete["address"].replace("Chicago O'hare International Airport remote lot E.", "ORD")
address_df_complete
# Out:
#         Tow Date  Make Style Color     Plate State  \
# 0     2019-03-21  ACUR    4T   BLK   AZ38933    IL
# 1     2019-03-21  AUDI    LL   BLK   AW30759    IL
# 2     2019-03-21  AUDI    SW   DBL   TAIRRE1    IL
# 3     2019-03-21   BMW    LL   BLK   AT56204    IL
# 4     2019-03-21  BUIC    4D   GRN   BD73021    IL
# 5     2019-03-21  BUIC    4D   SIL   AQ71209    IL
# 6     2019-03-21  CHEV    4D   BLU   AK55467    IL
# 7     2019-03-21  CHEV    LL   DBL   ZU11859    IL
# 8     2019-03-21  CHEV    VN   GLD   AW27879    IL
# 9     2019-03-21  CHRY    4D   GRY   AJ52258    IL
# 10    2019-03-21  DODG    4D   GRY   AQ71724    IL
# 11    2019-03-21  DODG    4T   WHI   BA54384    IL
# 12    2019-03-21  DODG    LL   GRY   ZZ30931    IL
# 13    2019-03-21  DODG    VN   MAR    PVR136    IL
# 14    2019-03-21  DODG    VN   SIL    637540    IL
# 15    2019-03-21  FORD    2T   BLK   BA59118    IL
# 16    2019-03-21  FORD    4D   BLK    6741WS    IL
# ...

# %%
sns.set()

# Set up the matplotlib figure
#f, ax = plt.subplots(figsize=(48, 3))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

#sns.set_context("paper")

#f.set_size_inches(20,20)

plt.figure(figsize=(120, 20))

# x = sns.heatmap((pd.crosstab[address_df_complete.address], [address_df_complete.State]), 
#             #ax=ax, cbar_ax = cbar_ax, cbar=True)
#             cmap="YlGnBu", vmax=.5, center=0,
#              square=True, linewidths=1, cbar_kws={"shrink": 1})    

x = sns.heatmap(pd.crosstab([address_df_complete.address],[address_df_complete.State]), 
            #ax=ax, cbar_ax = cbar_ax, cbar=True)
            cmap="YlGnBu", vmax=.5, center=0,
             square=True, linewidths=15, cbar_kws={"shrink": .1})            
#           cmap="YlGnBu", annot=True, cbar=False)
# fig, ax = plt.subplots(1, 1)
# cbar_ax = fig.add_axes([.905, .3, .05, .3])
# sns.heatmap(arr, ax=ax, cbar_ax = cbar_ax, cbar=True)

#plt.show()
#plt.show(block=False)
#plt.savefig('fig2.png')
plt.xlabel("States",fontsize=80)
plt.ylabel("Tow Lot",fontsize=80)
x.tick_params(labelsize=80)
plt.xticks(rotation=90)
plt.yticks(rotation=0)

#fig.savefig('fig2.pdf')
plt.savefig('Figures/fig2.png')
plt.show()



# #create a column showing the percentage of cars towed to a facility wtih Illinois plates
# sns.heatmap(pd.crosstab([address_df_complete.address],[address_df_complete.State])[address_df_complete.State]), 
#                         cmap="YlGnBu", annot=True, cbar=False)

#sns.heatmap(pd.crosstab([address_df_complete.State, address_df_complete.address],[address_df_complete.State, address_df_complete.address]),
            #cmap="YlGnBu", annot=True, cbar=False)

# %%
# # import csv
# file = "address.csv"
# address_df=pd.read_csv(file)
# address_df.head()

# %%
#Heatmap of Towed to Address
# Configure gmaps with API key
gmaps.configure(api_key="AIzaSyAMb9LRRnNqpIAaIzRvwHYNs6V5N5Hk5dU")

# %%
address_df = pd.read_csv("address.csv")
address_df.head()

# with open('address.csv', 'w') as csvfile:
#     fieldnames = ['address', 'Lat', 'Lng', "Count"]
#     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)


#Store 'Lat' and 'Lng' into locations
locations = address_df[["Lat", "Lng"]].astype(float)
Count = address_df["Count"].astype(float)

# %%
#Crate Heatmap layer
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=Count, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = 1

fig.add_layer(heat_layer)

fig
